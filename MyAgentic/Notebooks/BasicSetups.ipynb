# %% [markdown]
# # key Setup 🗝️
# Loading Environment variables with .env on config file

# %%
import os
from dotenv import load_dotenv
envpath = os.path.join(os.getcwd(),"../../config/.env")
load_dotenv(envpath)
if os.environ["LANGCHAIN_API_KEY"]:
    print("got the key")
# Out:
# got the key

# %% [markdown]
# # Lad The Pdf and text data from Data Folder

# %%
from
