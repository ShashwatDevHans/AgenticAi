# %% [markdown]
# # key Setup 🗝️
# Loading Environment variables with .env on config file

# %% [markdown]
# ## Remark ✅

# %%
import os
from dotenv import load_dotenv
envpath = os.path.join(os.getcwd(),"../../config/.env")
load_dotenv(envpath)
if os.environ["LANGCHAIN_API_KEY"]:
    print("got the key")
# Out:
# got the key

# %% [markdown]
# # Load The Pdf and text data from Data Folder

# %% [markdown]
# ## Remark ✅

# %%
from langchain_community.document_loaders import pdf
path_to_data = os.path.join(os.getcwd(),"../../Data")
pdfPath = os.path.join(path_to_data,"Obama_DNC_Speech.pdf")
doc = pdf.PyMuPDFLoader(pdfPath)
documents = doc.load()
documents[0].page_content
